# %%
#going to want create an instance of the the Dekel profile and give it the final state parameters so it can 
#just call rho(radius) etc and plot 
import numpy as np
import astropy.units as u
import pandas as pd
import astropy.constants as const
import matplotlib as mpl
import matplotlib.pyplot as plt
from glob import iglob
import glob
import random
# Out:
# /home/dropulic/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
from scipy.signal import argrelmin, argrelextrema, argrelmax
import numpy.ma as ma

# %%
import sys
sys.path.insert(0, '/tigress/dropulic/SatGen/')
import aux
import orbit as orb
from scipy.interpolate import interp1d
from profiles import Dekel, MN, EnergyAngMomGivenRpRa, Phi
from galhalo import Reff
#mass, DekelConcentration, DekelSlope, VirialOverdensity
#halo = Dekel(117781540.8609773, 3.0486991 ,1.4538499, 227.27994,z=0.)
import os
#import astropy
#from astropy.cosmology import FlatLambdaCDM
#cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

#import astropy.units as u
#import astropy.cosmology.units as cu
#u.add_enabled_units(cu)
# Out:
# >>> Normalizing primordial power spectrum P(k)=(k/k_0)^n_s ...
#     such that sigma(R=8Mpc/h) =   0.8000.
# >>> Tabulating sigma(M,z=0) ...
#     From now on, sigma(M,z) is computed by interpolation.
# >>> Tabulating z(W) and z(t_lkbk)...
# >>> Preparing output redshifts for merger trees ...
#     Number of output redshifts =  354, up to z = 20.06
# >>> Tabulating Parkinson+08 J(u_res) ...
# >>> Building interpolation grid for Green+19 M(<r|f_b,c)...
# >>> Building interpolation grid for Green+19 sigma(r|f_b,c)...
# >>> Building interpolation grid for Green+19 d2Phidr2(r|f_b,c)...
# >>> Building interpolator for Jiang+15 orbit sampler...

# %%
import load_galaxy

# %%
galaxy = load_galaxy.Galaxy()
# Out:
# /scratch/gpfs/dropulic/power_spectrum/SatGen_trees/SatGen/OUTPUT_SAT_MW_fd0.05_fb0.00_NIHAO_SatEvo_Mres3/tree769_lgM12.38.npz
# flattening 25.0
# disk fraction 0.05
# stellar_mass_floor 500000.0
# (10670,)
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]

# %%
print("Attributes of the Galaxy object:", list(vars(galaxy).keys()))
# Out:
# Attributes of the Galaxy object: ['flattening', 'fd', 'stellar_mass_floor', 'host_coords_alltime_list', 'idx_zaccs', 'pericenter_locs', 'apocenter_locs', 'all_apo', 'all_peri', 'coordinates_peri', 'coordinates_apo', 'velocities_apo', 'velocities_peri', 'coordinates_hold', 'velocities_hold', 'velocity_dispersion', 'sat_disk_rhobar', 'sat_stellar_disk_rhobar', 's001s', 'rhs', 'rh_halfs', 'rho_bars', 'mass_ratios', 'ras', 'rps', 'eccs', 'mass_lost_alls', 'stellar_mass_lost_alls', 'sat_distances', 'coordinates_SG', 'CosmicTime', 'host_Mvir', 'order_variable_SG', 'parentid_SG', 'host_mstar', 'zacc_idx_SG', 'host_coord', 'host_Rvir', 'redshift', 'host_conc', 'host_at_Mvir', 'host_at_dconc', 'host_at_slope', 'host_at_vovd', 'host_at_rvir', 'host_at_mstar', 'order3_locs_SG', 'parent_zacc_SG', 'host_coords_dekel', 'host_coords_alltime', 'array_s', 'vels_array_s', 'z', 'x', 'y', 'sat_final_mvir', 'sat_final_rvir', 'sat_final_mstar', 'Rvirs', 'Dekel_conc_s', 'Dekel_slope_s', 'Dekel_virialovd_s'
# ...

# %%
mapped_attributes = [
    'mass_lost_alls',  # np.log10(mass_lost_all[sat_i])
    'rps',  # np.log10(peri[sat_i])
    'rh_halfs',  # np.log10(R_half[sat_i]*1000)
    'mass_ratios',  # np.log10(M_star_over_halo[sat_i])
    'rho_bars',  # np.log10(rho_half[sat_i]+sat_stellar_disk_rhobar_half[sat_i])
    'ras',  # apo[sat_i]
    'eccs',  # ecc[sat_i]
    'sat_final_mstar',  # np.log10(M_star[sat_i].round(0))
    'sat_final_mvir',  # np.log10(M_halo[sat_i].round(0))
    'sat_final_rvir',  # R_vir[sat_i]
    'stellar_mass_lost_alls',  # np.log10(stellar_mass_lost_all[sat_i])
    'CosmicTime',  # cosmo.age(redshift[idx_zaccreted[sat_i]]*cu.redshift)/u.Gyr
    'allz_mstar_s',  # allz_mstar[sat_i,:]
    'allz_m_s',  # allz_m[sat_i,:]
    'sat_distances',  # sat_distances[sat_i]
    'pericenter_locs',  # pericenter_locs[sat_i]
    'apocenter_locs',  # apocenter_locs[sat_i]
    'CosmicTime',  # np.diff(cosmo.age(redshift[apocenter_locs[sat_i]])/u.Gyr)
    'coordinates_apo',  # coord_apo[sat_i]
    'coordinates_peri',  # coord_peri[sat_i]
    'velocities_apo',  # vel_apo[sat_i]
    'all_apo',  # all_apo_list[sat_i]
    'all_peri',  # all_peri_list[sat_i]
    'CosmicTime',  # 14 - cosmo.age(redshift[idx_zaccreted[sat_i]]*cu.redshift)/u.Gyr
    'num_sat_s',  # host_number[sat_i]
    'allz_mstar_s',  # np.max(allz_mstar[sat_i,:], axis = 0)
    'z',  # coord[sat_i,:,2]
    'x',  # np.multiply(coord[sat_i,:,0], np.cos(coord[sat_i,:,1]))[:]
    'y',  # np.multiply(coord[sat_i,:,0], np.sin(coord[sat_i,:,1]))[:]
    'idx_zaccs',  # idx_zaccreted[sat_i]
    'num_sat_s',  # sat_nums[sat_i]
    'coordinates_hold',  # coord[sat_i]
    'velocity_dispersion',  # velocity_dispersion_z0[sat_i]
    'coordinates_hold',  # coord_arr[sat_i]
    'velocities_hold',  # vel_arr[sat_i]
    's001s',  # s001_val[sat_i]
    'allz_mstar_s',  # allz_mstar[sat_i,idx_zaccreted[sat_i]]
    'allz_m_s',  # allz_m[sat_i,idx_zaccreted[sat_i]]
    'velocities_peri',  # vel_peri[sat_i]
    'redshift'
]

# %%
substructure_df = galaxy.get_filtered_rows_as_dataframe(mapped_attributes)

# %%
columns_to_log10 = [
    'mass_lost_alls', 
    'rps', 
    'rh_halfs', 
    'mass_ratios', 
    'rho_bars', 
    'sat_final_mstar', 
    'sat_final_mvir', 
    'stellar_mass_lost_alls'
]

# Apply np.log10 to the specified columns
substructure_df[columns_to_log10] = substructure_df[columns_to_log10].apply(np.log10)

# %%
# Display the transformed DataFrame
print(substructure_df.columns)
# Out:
# Index(['mass_lost_alls', 'rps', 'rh_halfs', 'mass_ratios', 'rho_bars', 'ras',
#        'eccs', 'sat_final_mstar', 'sat_final_mvir', 'sat_final_rvir',
#        'stellar_mass_lost_alls', 'CosmicTime', 'allz_mstar_s', 'allz_m_s',
#        'sat_distances', 'pericenter_locs', 'apocenter_locs', 'coordinates_apo',
#        'coordinates_peri', 'velocities_apo', 'all_apo', 'all_peri',
#        'num_sat_s', 'z', 'x', 'y', 'idx_zaccs', 'coordinates_hold',
#        'velocity_dispersion', 'velocities_hold', 's001s', 'velocities_peri',
#        'redshift', 'origin_masses', 'time_between_apocenters'],
#       dtype='object')

# %%
import substructure
subs = substructure.Substructure(substructure_df, 'trial', galaxy)
subs.main_processing_loop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3554911/1506872245.py in <module>
#       1 import substructure
#       2 subs = substructure.Substructure(substructure_df, 'trial', galaxy)
# ----> 3 subs.main_processing_loop()
#
# /scratch/gpfs/dropulic/StreamGen/StreamGen_package/substructure.py in main_processing_loop(self)
#     316     def main_processing_loop(self):
#     317         for sat_i in range(len(self.df)):
# --> 318             self.perform_calculations(sat_i)
#
# /scratch/gpfs/dropulic/StreamGen/StreamGen_package/substructure.py in perform_calculations(self, sat_i)
#     161
#     162         coords_cart, vels_cart = helpers.rvcyltocart(coord_peris1[0], vel_peris1[0])
# --> 163         E, L = helpers.EnergyAngMom(coords_cart, vels_cart, Phi(self.galaxy.get_host_profile(self, 0), np.linalg.norm(coords_cart)), allz_m1[0])
# ...

# %%
import corner
import pandas as pd

def plot_corner(rh, rho_half, R_half, M_star_over_halo, peri, apo, ecc, M_star, M_halo, R_vir,galaxy_no , 
                host_coords_dekel, stellar_mass_lost_all, mass_lost_all, redshift, sat_disk_rhobar_half,
                sat_stellar_disk_rhobar_half, idx_zaccreted, allz_mstar, allz_m, pericenter_locs, apocenter_locs, sat_distances, host_number, 
                all_apo_list, all_peri_list, coord_apo, coord_peri, coord, host_coords_at, orders, parentids, parent_zacc, sat_nums, vel_apo,velocity_dispersion_z0,coord_arr, vel_arr, host_in,s001_val, vel_peri, tags,rank,size):

    
    id_sat_stream = []
    id_sat_stream_zp99 = []
    id_ss_SatGen = []
    lookback = []
    peri_all_reintegrate = []
    apo_all_reintegrate = []
    peri_all_reintegrate_zp99 = []
    apo_all_reintegrate_zp99 = []
    PL_over_PE_arr = []
    PL_over_PE_arr_zp99 = []
    PE_list_zp99 = []
    PL_list_zp99 = []
    PE_list = []
    PL_list = []
    host_profiles = []
    Norb_list = []
    real_zp99_TF_list = []
    sats_per_gal.append(len(df))
    tag = tag #this is the filename

    for sat_i in range(6,7): #some MC'd orbits do this super-decay thing and take too long #6,7#13,14
        coords_cart, vels_cart = rvcyltocart(coord_peris1[sat_i][0], vel_peris1[sat_i][0])
        E,L = EnergyAngMom(coords_cart, vels_cart, Phi(prof_list[host_in],np.linalg.norm(coords_cart)),allz_m1[sat_i,0])
        E,L = EnergyAngMomGivenRpRa(prof_list[host_in],all_peris1[sat_i][0],all_apos1[sat_i][0])

        idx_zacc = idx_zaccreted1[sat_i]
        dists = sat_distances1[sat_i][0:idx_zacc]
        origin_mass = np.max(allz_mstar1[sat_i,:idx_zacc][allz_mstar1[sat_i,:idx_zacc] != -99], axis = 0)
        lookback.append(14 - cosmo.age(redshift[idx_zacc]*cu.redshift)/u.Gyr)
        mstar_over_mstartot = np.log10(allz_mstar1[sat_i,:idx_zacc][allz_mstar1[sat_i,:idx_zacc] != -99]/origin_mass)[0:idx_zacc]
        Norb_list.append(len(all_peris1[sat_i]))
        pericenter_locs_hold = []
        apocenter_locs_hold = []
        all_apos_hold = []
        all_peris_hold = []
        all_vels_apo = []
        time_between_apo_hold = []
        idx_zp99 = 0
        idx_zp99_hold = 0
        try:
            idx_mass_res = np.where((allz_m1[sat_i,:][0:idx_zacc] <= 10**(6)))[0][-1]
            idx_mass_res_hold = 0
        except:
            idx_mass_res = 0
            idx_mass_res_hold = 0
        entered = False
        entered_zp99 = False
        peri_num = 0
        for elem_i,elem_j,elem_k in zip(pericenter_locs1[sat_i],all_peris1[sat_i],time_between_apocenters[sat_i]):
            if elem_i < idx_zacc:
                pericenter_locs_hold.append(elem_i)
                all_peris_hold.append(elem_j)
                time_between_apo_hold.append(elem_k)
                if (elem_i > idx_mass_res) and (entered == False) and (idx_mass_res != 0): 
                    idx_mass_res_hold = peri_num
                    entered = True
                if (elem_i > idx_zp99) and (entered_zp99 == False) and (idx_zp99 != 0): 
                    idx_zp99_hold = peri_num
                    entered_zp99 = True
                peri_num += 1
        for elem_i,elem_j in zip(apocenter_locs1[sat_i],all_apos1[sat_i]):
            if elem_i < idx_zacc:
                apocenter_locs_hold.append(elem_i)
                all_apos_hold.append(elem_j)
        if len(pericenter_locs_hold) > len(apocenter_locs_hold):
            pericenter_locs_hold = pericenter_locs_hold[0:len(apocenter_locs_hold)]
            apocenter_locs_hold = apocenter_locs_hold
        elif len(pericenter_locs_hold) < len(apocenter_locs_hold):
            apocenter_locs_hold = apocenter_locs_hold[0:len(pericenter_locs_hold)]
            pericenter_locs_hold = pericenter_locs_hold
        Norb_zp99 = 1
        Norb_z0 = len(pericenter_locs_hold)
        if len(pericenter_locs_hold) < 1:
            Norb_z0 = 1

        try:
            idx_zp99 = pericenter_locs_hold[0]#np.where((np.divide(allz_m1[sat_i,:][0:idx_zacc],allz_m1[sat_i,idx_zacc]) <= 1/300))[0][-1]
            Norb_zp99 = len(pericenter_locs_hold) - 1
        except:
            idx_zp99 = 0
        real_zp99 = False
        try:    
            real_idx_zp99 = np.where((np.divide(allz_m1[sat_i,:][0:idx_zacc],allz_m1[sat_i,idx_zacc]) <= 1/300))[0][-1]
            real_zp99 = False
            if real_idx_zp99 > idx_zp99:
                idx_zp99 = real_idx_zp99
                real_zp99 = True
                try: 
                    p_i = 0
                    for perii in pericenter_locs_hold[1:]:
                        p_i+=1
                        if idx_zp99 < perii:
                            idx_zp99 = perii
                            Norb_zp99 = len(pericenter_locs_hold)- p_i
                            break;
                except:
                    print('idx_zp99 is not a pericenter')
        except:
            real_zp99 = False

        real_zp99_TF_list.append(real_zp99)
        print('idx_zp99',idx_zp99)
        print('pericenter_locs_hold',pericenter_locs_hold)
        print('apocenter_locs_hold',apocenter_locs_hold)
        print('Norb_zp99',Norb_zp99)
        print('Norb_z0',Norb_z0)

        zacc_mass = np.max(allz_m1[sat_i,:idx_zacc], axis = 0)
        idx_high = idx_zacc
        if len(pericenter_locs1[sat_i]) > 1:
            idx_high = pericenter_locs1[sat_i][-2]

        time_untilmassres = cosmo.age(redshift[idx_mass_res:idx_high]*cu.redshift)/u.Gyr
        m_over_mtot_untilmassres = np.log10(allz_m1[sat_i,idx_mass_res:idx_high]/zacc_mass)
        mod_sat_mass_at_pericenter_final = allz_m1[sat_i,pericenter_locs_hold]
        mod_mass_at = allz_m1[sat_i,:]#*0.125 ##TEMP TO CHECK HOW THIS AFFECT THE TIDAL RADIUS/ MORPHOLOGY METRIC

        dekel_host_coords = []
        dekel_host_coords_at = []
        if len(host_coords_dekel) == 1:
            dekel_host_coords = host_coords_dekel[0]
            dekel_host_coords_at = host_coords_at[0]
        else: 
            dekel_host_coords = host_coords_dekel[host_nums[sat_i],:][0]
            dekel_host_coords_at = host_coords_at[host_nums[sat_i]]

        ecc_est = 0.0
        ecc_est_zp99 = 0.0
        if (len(all_apos_hold) > 1) and (len(all_peris_hold) > 1):
            ecc_est = (all_apos_hold[0] - all_peris_hold[0])/(all_apos_hold[0] + all_peris_hold[0])
            ecc_est_zp99 = (all_apos_hold[idx_zp99_hold] - all_peris_hold[idx_zp99_hold])/(all_apos_hold[idx_zp99_hold] + all_peris_hold[idx_zp99_hold])
        print('ecc_est', ecc_est)
        print('ecc_est_zp99', ecc_est_zp99)
        print('IDX_ZP99_HOLD', idx_zp99_hold)
        
        str_mass = "{:.2e}".format(zacc_mass)
        sat_tag = 'zaccidx_'+str(idx_zacc)+'_zaccmass_'+str_mass
        print('sat_tag',sat_tag)
        #continue;
        
        ###MONTE-CARLO
        num_mc = 300
        ca_mc = []
        cp_mc = []
        vels_peri_mc = []
        vels_apo_mc = []
        satdist_mc = []
        t_mc = []
        tba_mc = []
        ca_mc_alt = []
        cp_mc_alt = []
        vels_peri_mc_alt = []
        vels_apo_mc_alt = []
        satdist_mc_alt = []
        host_total_profile = []
        host_total_profile_alt = []
        t_mc_alt = []
        tba_mc_alt = []
        ca_mc_zp99 = []
        cp_mc_zp99 = []
        vels_peri_mc_zp99 = []
        vels_apo_mc_zp99 = []
        satdist_mc_zp99 = []
        t_mc_zp99 = []
        tba_mc_zp99 = []
        inLLcorner_sat = False
        try: 
            #old forward from z = 0
            timetot, Nstep, tmax, pos_vel, min_loc, max_loc, satdist, t = integrate_orbit(coord1[sat_i], dekel_host_coords_at,mod_mass_at, 0, time_between_apocenters[sat_i], ecc_est, forward = True)
            half_period_locs_fwd, rosette_angle_fwd = calc_rosette_angle(max_loc, min_loc, pos_vel)
            rosette_angle_fwd_fit = get_huber_predictons(t[max_loc[0:len(rosette_angle_fwd)]], np.array(rosette_angle_fwd))
            all_ap_zp99o, all_peri, ca, cp, tba, vels_peri, vels_apo = peri_apo_props_reintegrate(timetot, Nstep, tmax, pos_vel, min_loc, max_loc, satdist, t)
            id_ss_fwd, PE_fwd, PL_fwd, deltaPsiarr_fwd, mod_deltaPsiarr_fwd, Lsat_fwd, Esat_fwd, n_orb ,Lmod_sat, Emod_sat, fit_PL_PE_fwd, M_Rp_arr_fwd= stream_or_shell_integrate_OLD(mod_mass_at, satdist[min_loc], all_peri, all_apo, cp, ca, tba, dekel_host_coords_at, 0, t+ np.max(cosmo.age(redshift[0:idx_zacc]*cu.redshift)/u.Gyr), max_loc, ax2,Norb_z0,vels_apo ,min_loc, rosette_angle_fwd_fit, vels_peri, forward = True)
            inLLcorner_sat = False 
        
            if (all_apo[0]<100) and (all_peri[0]<20):
                inLLcorner_sat = True
        except:
            inLLcorner_sat = False
            Esat_fwd = []
        if real_zp99 == True:
            tag_zp99 = tag+'zp99'+str(idx_zp99)
        else:
            tag_zp99 = tag +'peri'+str(idx_zp99)
        print(tag_zp99)

        #check to see whether files exist
        file_mc = '/scratch/gpfs/dropulic/power_spectrum/MC_saved_data/'+infolder+'/'+tag+'/'
        if not os.path.exists(file_mc):
            os.makedirs(file_mc)
            print("Directory created:", file_mc)
        else:
            print("Directory already exists:", file_mc)
        path_file_mc = file_mc+'ca_mc_'+sat_tag+'_'+tag+'.npy'
        path_file_mc_alt = file_mc+'ca_mc_'+sat_tag+'_'+tag_zp99+'.npy'
        print(path_file_mc_alt)
        isExist = os.path.exists(path_file_mc)
        isExist_alt = os.path.exists(path_file_mc_alt)
        print('isExist',isExist)
        print('isExist_alt',isExist_alt)
        print(path_file_mc)

        if isExist:
            try:
                ca_mc = np.load(file_mc+'ca_mc_'+sat_tag+'_'+tag+'.npy', allow_pickle=True)
                cp_mc= np.load(file_mc+'cp_mc_'+sat_tag+'_'+tag+'.npy', allow_pickle=True)
                vels_peri_mc = np.load(file_mc+'vels_peri_mc_'+sat_tag+'_'+tag+'.npy', allow_pickle=True)
                vels_apo_mc = np.load(file_mc+'vels_apo_mc_'+sat_tag+'_'+tag+'.npy', allow_pickle=True)
                satdist_mc = np.load(file_mc+'satdist_mc_'+sat_tag+'_'+tag+'.npy', allow_pickle=True)
                t_mc = np.load(file_mc+'t_mc_'+sat_tag+'_'+tag+'.npy', allow_pickle=True)
                tba_mc = np.load(file_mc+'tba_mc_'+sat_tag+'_'+tag+'.npy', allow_pickle=True)
                host_total_profile = np.load(file_mc+'host_total_profile_'+sat_tag+'_'+tag+'.npy', allow_pickle=True)
                host_total_profile = prof_list[0]#host_total_profile[0]
                pos_vel_list_mc = np.load(file_mc+'pos_vel_'+sat_tag+'_'+tag+'.npy', allow_pickle=True)
                host_profiles.append(host_total_profile)
                print(np.round(satdist_mc[0][0]))
                print(np.round(np.linalg.norm(coord1[sat_i][0][:3])))
                print('loaded files z = 0')
                print('ca_mc',ca_mc[0])
            except:
                print('file does not exist')
                ca_mc, cp_mc, vels_peri_mc, vels_apo_mc, satdist_mc, t_mc,tba_mc, host_total_profile, pos_vel_mc = integrate_mc_orbits(coord1[sat_i],vel_disp_z0[sat_i],coord1[sat_i], dekel_host_coords_at,mod_mass_at, 0, time_between_apocenters[sat_i], ecc_est,num_mc ,forward = True, inLLcorner = inLLcorner_sat)
                np.save(file_mc +'ca_mc_'+sat_tag+'_'+tag, np.array(ca_mc, dtype=object), allow_pickle=True)
                np.save(file_mc +'cp_mc_'+sat_tag+'_'+tag, np.array(cp_mc, dtype=object), allow_pickle=True)
                np.save(file_mc +'vels_peri_mc_'+sat_tag+'_'+tag, np.array(vels_peri_mc, dtype=object), allow_pickle=True)
                np.save(file_mc +'vels_apo_mc_'+sat_tag+'_'+tag, np.array(vels_apo_mc, dtype=object), allow_pickle=True)
                np.save(file_mc +'satdist_mc_'+sat_tag+'_'+tag, np.array(satdist_mc, dtype=object), allow_pickle=True)
                np.save(file_mc +'t_mc_'+sat_tag+'_'+tag, np.array(t_mc, dtype=object), allow_pickle=True)
                np.save(file_mc +'tba_mc_'+sat_tag+'_'+tag, np.array(tba_mc, dtype=object), allow_pickle=True)
                np.save(file_mc +'host_total_profile_'+sat_tag+'_'+tag, np.array(host_total_profile, dtype=object), allow_pickle=True)
                np.save(file_mc +'pos_vel_'+sat_tag+'_'+tag, np.array(pos_vel_mc, dtype=object), allow_pickle=True)

            
        if isExist_alt:
            redshift_id = idx_zp99
            try:
                ca_mc_zp99 = np.load(file_mc+'ca_mc_'+sat_tag+'_'+tag_zp99+'.npy', allow_pickle=True)
                cp_mc_zp99= np.load(file_mc+'cp_mc_'+sat_tag+'_'+tag_zp99+'.npy', allow_pickle=True)
                vels_peri_mc_zp99 = np.load(file_mc+'vels_peri_mc_'+sat_tag+'_'+tag_zp99+'.npy', allow_pickle=True)
                vels_apo_mc_zp99 = np.load(file_mc+'vels_apo_mc_'+sat_tag+'_'+tag_zp99+'.npy', allow_pickle=True)
                satdist_mc_zp99 = np.load(file_mc+'satdist_mc_'+sat_tag+'_'+tag_zp99+'.npy', allow_pickle=True)
                t_mc_zp99 = np.load(file_mc+'t_mc_'+sat_tag+'_'+tag_zp99+'.npy', allow_pickle=True)
                tba_mc_zp99 = np.load(file_mc+'tba_mc_'+sat_tag+'_'+tag_zp99+'.npy', allow_pickle=True)
                #host_total_profile_alt = np.load(file_mc+'host_total_profile_'+sat_tag+'_'+tag_zp99+'_100.npy', allow_pickle=True)
                pos_vel_list_mc_zp99 = np.load(file_mc+'pos_vel_'+sat_tag+'_'+tag_zp99+'.npy', allow_pickle=True)
                host_profile = Dekel(dekel_host_coords_at[0,redshift_id],dekel_host_coords_at[1,redshift_id],dekel_host_coords_at[2,redshift_id],dekel_host_coords_at[3,redshift_id],z=0.)
                r_half_host = Reff(dekel_host_coords_at[4,redshift_id],host_profile.ch)
                disk_scale_length_host = 0.766421/(1.+1./flattening) * r_half_host
                disk_scale_height_host = disk_scale_length_host / flattening
                #define the host disk profile
                host_disk_profile = MN(dekel_host_coords_at[0,redshift_id]*fd,disk_scale_length_host,disk_scale_height_host )
                host_stellar_disk_profile = MN(dekel_host_coords_at[5,redshift_id]*fd,disk_scale_length_host,disk_scale_height_host )
                total_profile = [host_profile,host_disk_profile]#,host_disk_profile #TOOK OUT THE DISK
                host_total_profile_zp99 = total_profile#host_total_profile_alt[0] 
                host_profiles.append(host_total_profile_zp99) #don't do this twice

            except:
                print('file 99 does not exist')
                ca_mc_zp99, cp_mc_zp99, vels_peri_mc_zp99, vels_apo_mc_zp99, satdist_mc_zp99, t_mc_zp99,tba_mc_zp99, host_total_profile_zp99, pos_vel_zp99 = integrate_mc_orbits(coord1[sat_i],vel_disp_z0[sat_i],coord1[sat_i], dekel_host_coords_at,mod_mass_at, redshift_id, time_between_apocenters[sat_i], ecc_est_zp99,num_mc,period_est_correction = idx_zp99_hold ,forward = True, inLLcorner = inLLcorner_sat)
                np.save(file_mc+'ca_mc_'+sat_tag+'_'+tag_zp99, np.array(ca_mc, dtype=object), allow_pickle=True)
                np.save(file_mc+'cp_mc_'+sat_tag+'_'+tag_zp99, np.array(cp_mc_zp99, dtype=object), allow_pickle=True)
                np.save(file_mc+'vels_peri_mc_'+sat_tag+'_'+tag_zp99, np.array(vels_peri_mc_zp99, dtype=object), allow_pickle=True)
                np.save(file_mc+'vels_apo_mc_'+sat_tag+'_'+tag_zp99, np.array(vels_apo_mc_zp99, dtype=object), allow_pickle=True)
                np.save(file_mc+'satdist_mc_'+sat_tag+'_'+tag_zp99, np.array(satdist_mc_zp99, dtype=object), allow_pickle=True)
                np.save(file_mc+'t_mc_'+sat_tag+'_'+tag_zp99, np.array(t_mc_zp99, dtype=object), allow_pickle=True)
                np.save(file_mc+'tba_mc_'+sat_tag+'_'+tag_zp99, np.array(tba_mc_zp99, dtype=object), allow_pickle=True)
                np.save(file_mc+'host_total_profile_'+sat_tag+'_'+tag_zp99, np.array(host_total_profile_zp99, dtype=object), allow_pickle=True)
                np.save(file_mc+'pos_vel_'+sat_tag+'_'+tag_zp99, np.array(pos_vel_zp99, dtype=object), allow_pickle=True)

        if  idx_zp99 > 0:
            #old forward from mass 1/300   
            timetot, Nstep, tmax, pos_vel, min_loc, max_loc, satdist, t = integrate_orbit(coord1[sat_i], dekel_host_coords_at,mod_mass_at, idx_zp99, time_between_apocenters[sat_i], ecc_est_zp99,period_est_correction = idx_zp99_hold, forward = True, inLLcorner = inLLcorner_sat)
            half_period_locs_fwd, rosette_angle_fwd = calc_rosette_angle(max_loc, min_loc, pos_vel)
            rosette_angle_fwd_fit = get_huber_predictons(t[max_loc[0:len(rosette_angle_fwd)]], np.array(rosette_angle_fwd))
            all_apo, all_peri, ca, cp, tba, vels_peri, vels_apo = peri_apo_props_reintegrate(timetot, Nstep, tmax, pos_vel, min_loc, max_loc, satdist, t)
            id_ss_fwd, PE_fwd, PL_fwd, deltaPsiarr_fwd, mod_deltaPsiarr_fwd, Lsat_fwd_zp99, Esat_fwd_zp99, n_orb ,Lmod_sat, Emod_sat, fit_PL_PE_fwd, M_Rp_arr_fwd= stream_or_shell_integrate_OLD(mod_mass_at, satdist[min_loc], all_peri, all_apo, cp, ca, tba, dekel_host_coords_at, idx_zp99, t+ np.max(cosmo.age(redshift[idx_zp99:idx_zacc]*cu.redshift)/u.Gyr), max_loc, ax2,Norb_zp99,vels_apo ,min_loc, rosette_angle_fwd_fit, vels_peri, forward = True)
            print(' Lsat_fwd_zp99', Lsat_fwd_zp99)
            print(' Esat_fwd_zp99', Esat_fwd_zp99)
        redshift_start = 0
        #old forward from z = 0
        if len(Esat_fwd) == 0 :
            print('Esat_fwd',Esat_fwd)
            
        if idx_zp99 > 0:
            if len(Esat_fwd_zp99) == 0 :
                print('Esat_fwd_zp99',Esat_fwd_zp99)

        
        half_period_locs_SG, rosette_angle_SG = calc_rosette_angle_SatGen(apocenter_locs_hold, pericenter_locs_hold, coord1[sat_i])
        id_ss, PE, PL, deltaPsiarr, Lsat, Esat, predictions_SG = stream_or_shell(mod_sat_mass_at_pericenter_final, dekel_host_coords, sat_distances1[sat_i][pericenter_locs_hold], all_peris_hold, 
                                                                 all_apos_hold, coord_peris1[sat_i], coord_apos1[sat_i], time_between_apocenters[sat_i], df_copy['mass_lost'].values[sat_i], dekel_host_coords_at[:,pericenter_locs_hold], idx_mass_res_hold, orders1[sat_i], vel_apo1[sat_i],cosmo.age(redshift[allz_mstar1[sat_i,:] != -99][0:idx_zacc]*cu.redshift)/u.Gyr,apocenter_locs_hold,rosette_angle_SG,vel_peris1[sat_i])
        id_ss_SatGen.append(id_ss)
        try:
            E = Esat_fwd[0]
            L = Lsat_fwd[0]   
        except:
            E = Esat[0]
            L = Lsat[0]
        mean_slope_L_Psi, mean_slope_E_tba  = detrivatives_metric(ax13, ca_mc, cp_mc, vels_peri_mc, vels_apo_mc, satdist_mc, t_mc, tba_mc, host_total_profile, mod_mass_at, E, L, num_mc, 0)
        
        if  idx_zp99 > 0:
            try:
                if len(Esat_fwd_zp99) > 0:
                    E_zp99 = Esat_fwd_zp99[0]
                    L_zp99 = Lsat_fwd_zp99[0]
                elif len(Esat) > 0:
                    E_zp99 = Esat[0]
                    L_zp99 = Lsat[0]
                else:
                    print('len(Esat_fwd_zp99) and len(Esat) are 0')
                    E_zp99 = E
                    L_zp99 = L
            except:
                E_zp99 = E
                L_zp99 = L
            mean_slope_L_Psi_zp99, mean_slope_E_tba_zp99  = detrivatives_metric(ax20, ca_mc_zp99, cp_mc_zp99, vels_peri_mc_zp99, vels_apo_mc_zp99, satdist_mc_zp99, t_mc_zp99, tba_mc_zp99, host_total_profile_zp99, mod_mass_at, E_zp99, L_zp99, num_mc, idx_zp99)
        print('mean_slope_L_Psi',mean_slope_L_Psi)
        print('mean_slope_E_tba',mean_slope_E_tba)

        if  idx_zp99 > 0:
            #forwards from idx_zp99
            timetot, Nstep, tmax, pos_vel_zp99, min_loc, max_loc, satdist, t = integrate_orbit(coord1[sat_i], dekel_host_coords_at,mod_mass_at, idx_zp99, time_between_apocenters[sat_i], ecc_est_zp99,period_est_correction = idx_zp99_hold, forward = True, inLLcorner = inLLcorner_sat)
            print('time_between_apocenters[idx_zp99_hold]',time_between_apocenters[idx_zp99_hold])
            half_period_locs_fwd, rosette_angle_fwd = calc_rosette_angle(max_loc, min_loc, pos_vel)
            rosette_angle_fwd_fit = get_huber_predictons(t[max_loc[0:len(rosette_angle_fwd)]], np.array(rosette_angle_fwd))
            all_apo, all_peri, ca, cp, tba, vels_peri, vels_apo = peri_apo_props_reintegrate(timetot, Nstep, tmax, pos_vel_zp99, min_loc, max_loc, satdist, t)
            id_ss_fwd_zp99, PE_fwd_zp99, PL_fwd_zp99, deltaPsiarr_fwd_zp99, mod_deltaPsiarr_fwd_zp99, Lsat_fwd_zp99, Esat_fwd_zp99, n_orb_zp99 ,Lmod_sat_zp99, Emod_sat_zp99, fit_PL_PE_fwd_zp99, M_Rp_arr_fwd_zp99 = stream_or_shell_integrate(mod_mass_at, satdist[min_loc], all_peri, all_apo, cp, ca, tba, dekel_host_coords_at, idx_zp99, t+ np.max(cosmo.age(redshift[idx_zp99:idx_zacc]*cu.redshift)/u.Gyr), max_loc, ax2,Norb_zp99,vels_peri ,min_loc, rosette_angle_fwd_fit, vel_disp_z0[sat_i], vel_arr1[sat_i][0], mean_slope_L_Psi_zp99, mean_slope_E_tba_zp99, forward = True)
            t = t + np.max(cosmo.age(redshift[idx_zp99:idx_zacc]*cu.redshift)/u.Gyr) 
            if len(all_peri > 0):
                peri_all_reintegrate_zp99.append(all_peri[0])
                apo_all_reintegrate_zp99.append(all_apo[0])
            else:
                peri_all_reintegrate_zp99.append(np.nan)
                apo_all_reintegrate_zp99.append(np.nan)
            try:
                if len(PL_fwd > 0):
                    PL_over_PE_arr_zp99.append(np.divide(PL_fwd_zp99[0], PE_fwd_zp99[0]))
                    PL_list_zp99.append(PL_fwd_zp99[0])
                    PE_list_zp99.append(PE_fwd_zp99[0])
                else:
                    PL_over_PE_arr_zp99.append(np.nan)  
                    PL_list_zp99.append(np.nan)
                    PE_list_zp99.append(np.nan)
            except:
                PL_over_PE_arr_zp99.append(np.nan)
                PL_list_zp99.append(np.nan)
                PE_list_zp99.append(np.nan)
                                         
            id_sat_stream_zp99.append(id_ss_fwd_zp99)
        else:
            peri_all_reintegrate_zp99.append(np.nan)
            apo_all_reintegrate_zp99.append(np.nan)
            id_sat_stream_zp99.append(np.nan)
            PL_over_PE_arr_zp99.append(np.nan)
            PL_list_zp99.append(np.nan)
            PE_list_zp99.append(np.nan)

        #forwards from z = 0
        timetot, Nstep, tmax, pos_vel, min_loc, max_loc, satdist, t = integrate_orbit(coord1[sat_i], dekel_host_coords_at,mod_mass_at, redshift_start, time_between_apocenters[sat_i], ecc_est, forward = True, inLLcorner = inLLcorner_sat)
        half_period_locs_fwd, rosette_angle_fwd = calc_rosette_angle(max_loc, min_loc, pos_vel)
        rosette_angle_fwd_fit = get_huber_predictons(t[max_loc[0:len(rosette_angle_fwd)]], np.array(rosette_angle_fwd))
        all_apo, all_peri, ca, cp, tba, vels_peri, vels_apo = peri_apo_props_reintegrate(timetot, Nstep, tmax, pos_vel, min_loc, max_loc, satdist, t)
        id_ss_fwd, PE_fwd, PL_fwd, deltaPsiarr_fwd, mod_deltaPsiarr_fwd, Lsat_fwd, Esat_fwd, n_orb ,Lmod_sat, Emod_sat, fit_PL_PE_fwd, M_Rp_arr_fwd= stream_or_shell_integrate(mod_mass_at, satdist[min_loc], all_peri, all_apo, cp, ca, tba, dekel_host_coords_at, redshift_start, t+ np.max(cosmo.age(redshift[0:idx_zacc]*cu.redshift)/u.Gyr), max_loc, ax2,Norb_z0,vels_peri ,min_loc, rosette_angle_fwd_fit, vel_disp_z0[sat_i], vel_arr1[sat_i][0], mean_slope_L_Psi, mean_slope_E_tba, forward = True)
        t = t + np.max(cosmo.age(redshift[0:idx_zacc]*cu.redshift)/u.Gyr) 
        
        if len(all_peri > 0):
            peri_all_reintegrate.append(all_peri[0])
            apo_all_reintegrate.append(all_apo[0])
        else:
            peri_all_reintegrate.append(np.nan)
            apo_all_reintegrate.append(np.nan)
        if len(PL_fwd > 0):
            PL_over_PE_arr.append(np.divide(PL_fwd[0], PE_fwd[0]))
            PL_list.append(PL_fwd[0])
            PE_list.append(PE_fwd[0])
        else:
            PL_over_PE_arr.append(np.nan)
            PL_list.append(np.nan)
            PE_list.append(np.nan)

        print('PE_fwd',PE_fwd)
        print('PL_fwd',PL_fwd)
        print(id_ss_fwd)

        id_sat_stream.append(id_ss_fwd)
                                         


    summary_plots(start,stop,df_copy,id_sat_stream,id_sat_stream_zp99,id_ss_SatGen,samp1,colors,host_profiles,allz_m1,peri_all_reintegrate,apo_all_reintegrate,peri_all_reintegrate_zp99,apo_all_reintegrate_zp99, s001_val1,PL_over_PE_arr,lookback, tag,n_bins_ranges, PL_list ,PE_list, PL_list_zp99, PE_list_zp99,real_zp99_TF_list,Norb_list)

    comm.Barrier()

# %%
def summary_plots(start,stop,df_copy,id_sat_stream,id_sat_stream_zp99,id_ss,samp1,colors,host_profiles,allz_m1,peri_all_reintegrate,apo_all_reintegrate,peri_all_reintegrate_zp99,apo_all_reintegrate_zp99,
                 s001_val1,PL_over_PE_arr,lookback, tag,n_bins_ranges, PL_list ,PE_list, PL_list_zp99, PE_list_zp99,real_zp99_TF_list,Norb_list):
    #orbit plot distance vs time 
    df_copy_temp = df_copy[start:stop].reset_index(drop = True)
    sat_num = stop - start
    tag_summary = tag +'_sats_'+str(start)+'_'+str(stop-1)
    print(df_copy_temp)
    print(PL_list)
    df_copy_temp['id_sat_stream'] = id_sat_stream
    df_copy_temp['id_sat_stream_zp99'] = id_sat_stream_zp99
    df_copy_temp['id_ss_SG'] = id_ss
    df_copy_temp['PL_list'] = PL_list
    df_copy_temp['PE_list'] = PE_list
    df_copy_temp['PL_list_zp99'] = PL_list_zp99
    df_copy_temp['PE_list_zp99'] = PE_list_zp99
    df_copy_temp['real_zp99_TF_list'] = real_zp99_TF_list
    df_copy_temp['Norb_list'] = Norb_list
    #print(df_copy['id_sat_stream'])
    df_copy_temp['marker'] = 'o'
    df_copy_temp['marker_zp99'] = 'o'
    df_copy_temp['marker_SG'] = 'o'
    #print(np.where(df_copy.id_sat_stream == 0))
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 0)[0],'marker'] = '.'
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 1)[0],'marker'] = '*'
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 2)[0],'marker'] = 'd'
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 3)[0],'marker'] = 's'
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 4)[0],'marker'] = 'v'
    
    df_copy_temp.loc[np.where(df_copy_temp.id_ss_SG == 0)[0],'marker_SG'] = '.'
    df_copy_temp.loc[np.where(df_copy_temp.id_ss_SG == 1)[0],'marker_SG'] = '*'
    df_copy_temp.loc[np.where(df_copy_temp.id_ss_SG == 2)[0],'marker_SG'] = 'd'
    df_copy_temp.loc[np.where(df_copy_temp.id_ss_SG == 3)[0],'marker_SG'] = 's'
    df_copy_temp.loc[np.where(df_copy_temp.id_ss_SG == 4)[0],'marker_SG'] = 'v'
    
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream_zp99 == 0)[0],'marker_zp99'] = '.'
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream_zp99 == 1)[0],'marker_zp99'] = '*'
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream_zp99 == 2)[0],'marker_zp99'] = 'd'
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream_zp99 == 3)[0],'marker_zp99'] = 's'
    df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream_zp99 == 4)[0],'marker_zp99'] = 'v'
  
    df_copy_temp['lookback_time'] = lookback
    df_copy_temp['peri_all_reintegrate'] = peri_all_reintegrate
    df_copy_temp['apo_all_reintegrate'] = apo_all_reintegrate
    df_copy_temp['peri_all_reintegrate_zp99'] = peri_all_reintegrate_zp99
    df_copy_temp['apo_all_reintegrate_zp99'] = apo_all_reintegrate_zp99
    df_copy_temp['s001'] = s001_val1[start:stop]
    
    fig7, ax7 = plt.subplots(nrows = 1, ncols = 1, sharex=False , sharey=False,figsize=(8,4))
    hist_0, bin_edges_0 = np.histogram(df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 0)[0]].lookback_time, bins = np.arange(0,16,2))
    hist_1, bin_edges_1 = np.histogram(df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 1)[0]].lookback_time, bins = np.arange(0,16,2))
    hist_2, bin_edges_2 = np.histogram(df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 2)[0]].lookback_time, bins = np.arange(0,16,2))
    bin_centers_0 = (bin_edges_0[1:]+bin_edges_0[:-1])/2
    bin_centers_1 = (bin_edges_1[1:]+bin_edges_1[:-1])/2
    bin_centers_2 = (bin_edges_2[1:]+bin_edges_2[:-1])/2
    hist_tot = hist_0 + hist_1 + hist_2
    ax7.plot(bin_centers_0, np.divide(hist_0, hist_tot), linestyle = '-', marker = 'o', color = 'purple', label = 'Intact satellite')
    ax7.plot(bin_centers_1, np.divide(hist_1, hist_tot), linestyle = '-', marker = 'o', color = 'blue', label = 'Stream')
    ax7.plot(bin_centers_2, np.divide(hist_2, hist_tot), linestyle = '-', marker = 'o', color = 'green', label = "Phase Mixed")
    ax7.invert_xaxis()
    ax7.legend()
    ax7.set_ylabel('fraction of systems')
    ax7.set_xlabel('Lookback $t_{acc}$ [Gyr]')
    
    fig8, ax8 = plt.subplots(nrows = 2, ncols = 1, sharex=False , sharey=False,figsize=(8,8))
    ax8[0].hist(10**df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 0)[0]].peri, range = [0,150], color = 'purple', label = 'Intact satellite', histtype = 'step', bins = 15, linewidth = 2, density = True, alpha = 0.5)
    ax8[0].hist(10**df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 1)[0]].peri, range = [0,150], color = 'blue', label = 'Stream', histtype = 'step', bins = 15, linewidth = 2, density = True, alpha = 0.5)
    ax8[0].hist(10**df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 2)[0]].peri, range = [0,150], color = 'green', label = "Phase Mixed", histtype = 'step', bins = 15, linewidth = 2, density = True, alpha = 0.5)
    #ax8[0].hist(Li_peri, range = [0,150], color = 'black', label = "MW", histtype = 'step', bins = 15, linewidth = 2, density = True, alpha = 0.5)#np.concatenate([pace_peri, Li_peri])

    
    ax8[1].hist(df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 0)[0]].apo, range = [0,450], color = 'purple', label = 'Intact satellite', histtype = 'step', bins = 15, linewidth = 2, density = True, alpha = 0.5)
    ax8[1].hist(df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 1)[0]].apo, range = [0,450], color = 'blue', label = 'Stream', histtype = 'step', bins = 15, linewidth = 2, density = True, alpha = 0.5)
    ax8[1].hist(df_copy_temp.loc[np.where(df_copy_temp.id_sat_stream == 2)[0]].apo, range = [0,450], color = 'green', label = "Phase Mixed", histtype = 'step', bins = 15, linewidth = 2, density = True, alpha = 0.5)
    #ax8[1].hist(Li_apo, range = [0,450], color = 'black', label = "MW", histtype = 'step', bins = 15, linewidth = 2, density = True, alpha = 0.5)

    ax8[0].legend()
    #ax8[0].set_ylabel('fraction of systems')
    ax8[0].set_xlabel('$r_{\mathrm{peri}}$ [kpc]')
    ax8[1].set_xlabel('$r_{\mathrm{apo}}$ [kpc]')
     
    fig9, ax9 = plt.subplots(nrows = 1, ncols = 1, sharex=False , sharey=False,figsize=(8,4))
    ax9.hist(no_UL_per_galaxy, bins = 10, color = 'green', label = 'UL', range = [0,50], alpha = 0.5, histtype = 'step', linewidth = 2)
    ax9.hist(no_UR_per_galaxy, bins = 10, color = 'purple', label = 'UR', range = [0,50], alpha = 0.5, histtype = 'step', linewidth = 2)
    ax9.hist(no_LL_per_galaxy, bins = 10, color = 'red', label = 'LL', range = [0,50], alpha = 0.5, histtype = 'step', linewidth = 2)
    ax9.hist(no_LR_per_galaxy, bins = 10, color = 'black', label = 'LR', range = [0,50], alpha = 0.5, histtype = 'step', linewidth = 2)
    ax9.set_xlabel('number of satellites in quadrant')
    ax9.legend()
    
    file_df = '/scratch/gpfs/dropulic/power_spectrum/saved_sat_data/'+infolder+'/wrealzp99_corrNorb/'
    if not os.path.exists(file_df):
        os.makedirs(file_df)
        print("Directory created:", file_df)
    else:
        print("Directory already exists:", file_df)
    # Convert the dataframe to a NumPy array
    df_copy_temp.to_csv(file_df + tag_summary+'_of_'+str(len(df_copy))+'.csv', index=False)
